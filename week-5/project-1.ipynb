# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def log(firstname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("GIG LOGISTICS DEPT.")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nLOGISTICS DEPARTMENT EMPLOYEES\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)ADENIRAN Oluwatamilore  \n2)AGBAKWURU Chiemeziem \n3)ARNIKA Osose \n4)CHUKWUMA Nedi \n5)EZEONYE Makuochukwu \n6)GIWA Moyosore \n7)NWOKOLO Chijindu \n8)NWOTOKUBO	Joseph \n9)OKORO Derek \n10)OSSAI Mary-Cynthia \n11)PETER Owoede')
    label_3.pack()

def acc(firstname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("GIG ACCOUNTING DEPT.")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nACCOUNTING DEPARTMENT EMPLOYEES\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)ADEWUMI Ayomide  \n2)AGBAKURU-NWOGU Chukwunonye \n3)AKINDE Oluwatimehin \n4)EBI Stephanie \n5)ICHA Ayonete \n6)IKPATI Eche \n7)OBAOSGIE Daisy \n8)OBI Samuel \n9)OBIALOR Betha \n10)OLOWOKERE Akorede \n11)Olubuade Rasheed \n12)Osemeke Daniel')
    label_3.pack()

def deli(firstname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("GIG DELIVERY DEPT.")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nDELIVERY DEPARTMENT EMPLOYEES\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)ADOH-AJAGBE Oshim \n2)ATELLY Daniel \n3)AZOGU Onyekachi \n4)BETURE Shalom \n5)EJEDIMU Edward \n6)ILOENYOSI Michael \n7)IYAWE Oluwadamilola \n8)OGBONNA Boluwatife \n9)OIGBOCHIE Mary \n10)QUADRI Oluwafikunmi \n11)UDE-IBE Uchenna')
    label_3.pack()

def admin(firstname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("GIG ADMINISTRATION DEPT.")
    window.geometry('500x300')

    label_1 = tk.Label(window, text=f'\nADMINISTRATION DEPARTMENT EMPLOYEES\n')
    label_1.pack()
    label_3=tk.Label(window,text='\nNAMES :\n1)EGBORO Jason \n2)ELERI Otu \n3)EZE Onyiyechi \n4)OKOCHA-OJEAH Raphael \n5)Okolo Victor \n6)UMEH Ejike')
    label_3.pack()

    
    #run the tkinter event loop
    root.mainloop()    
    
def submit():
    firstname = firstname_entry.get()
    department= department_entry.get()
    
    if firstname == 'Oluwatamilore' or firstname == 'Chiemeziem' or firstname=='Osose' or firstname=='Nedi' or firstname=='Makuochukwu'or firstname=='Moyosore' or firstname=='Chijindu' or firstname=='Joseph' or firstname=='Derek' or firstname=='Mary-cynthia' or firstname=='Owoede':
        if department == 'Logistics':
            messagebox.showinfo("Sucess",f"Welcome {firstname}")
            log(firstname)
                        
    elif firstname == 'Ayomide' or firstname=='Chukwunonye' or firstname=='Oluwatimehin' or firstname=='Stephanie' or firstname=='Ayonete' or firstname=='Eche' or firstname=='Daisy' or firstname=='Samuel' or firstname=='Betha' or firstname=='Akorede' or firstname=='Rasheed' or firstname=='Daniel':
        if department =='Accounting':
            messagebox.showinfo("Sucess",f"Welcome {firstname}")
            acc(firstname)
            
    elif firstname=='Oshim' or firstname=='Daniel' or firstname=='Onyekachi' or firstname=='Shalom' or firstname=='Edward' or firstname=='Michael' or firstname=='Oluwadamilola' or firstname=='Boluwatife' or firstname=='Mary' or firstname=='Oluwafikunmi' or firstname=='Uchenna':
        if department=='Delivery':
            messagebox.showinfo("Sucess",f"Welcome {firstname}")
            deli(firstname)
            
    elif firstname=='Jason' or firstname=='Onyiyechi' or firstname=='Otu' or firstname=='Raphael' or firstname=='Victor' or firstname=='Ejike':
        if department=='Administration':
            messagebox.showinfo("Sucess",f"Welcome {firstname}")
            admin(firstname)
        
    else:
        messagebox.showerror('LOGIN','This employee does not exist')

#create main window
root = tk.Tk()
root.title('LOGIN')
root.geometry('500x200')

#create firstname label and entry
firstname_label = tk.Label(root, text = 'Firstname(it is case sensitive)')
firstname_label.pack()
firstname_entry = tk.Entry(root, show='*')
firstname_entry.pack()

#create department label and entry
department_label = tk.Label(root, text = 'Department(it is case sensitive)')
department_label.pack()
department_entry = tk.Entry(root, show='*')
department_entry.pack()

#create submit button
submit_button = tk.Button(root, text = 'Submit', command=submit)
submit_button.pack()

#styling the button widget
submit_button.config(fg = 'black', bg = 'pink')

#run the main event loop
root.mainloop()
