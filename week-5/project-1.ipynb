# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

def correct(firstname):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("GIG LOGISTICS")
    window.geometry('500x300')
    
    label_1 = tk.Label(window, text=f'\nWelcome {firstname}\n')
    label_1.pack()
    label_2 = tk.Label(window, text='You have successfully logged into GIG LOGISTICS portal')
    label_2.pack()
def logistics(firstname):   
    label_3 = tk.Text(window, text='\nNAMES OF EMPLOYEES IN LOGISTICS DEPARTMENT:\n1)ADENIRAN Oluwatamilore  \n2)AGBAKWURU Chiemeziem \n3)ARNIKA Osose \n4)CHUKWUMA Nedi \n5)EZEONYE Makuochukwu \n6)GIWA Moyosore \n7)NWOKOLO Chijindu \n8)NWOTOKUBO	Joseph \n9)OKORO Derek \n10)OSSAI Mary-Cynthia \n11)PETER Owoede')
    label_3.pack()
    
    #run the tkinter event loop
    root.mainloop()

def submit():
    firstname = firstname_entry.get()
    department= department_entry.get()
    
    if firstname == 'Oluwatamilore' or firstname == 'Chiemeziem' or firstname=='Osose' or firstname=='Nedi' or firstname=='Makuochukwu'or firstname=='Moyosore' or firstname=='Chijindu' or firstname=='Joseph' or firstname=='Derek' or firstname=='Mary-cynthia' or firstname=='Owoede':
        if department == 'Logistics':
            correct(firstname)
            logistics(firstname)
    if firstname == 'Ayomide' or firstname=='Chukwunonye' or firstname=='Oluwatimehin' or firstname=='Stephanie' or firstname=='Ayonete' or firstname=='Eche' or firstname=='Daisy' or firstname=='Samuel' or firstname=='Betha' or firstname=='Akorede' or firstname=='Rasheed' or firstname=='Daniel':
        if department =='Accounting':
            correct(firstname)
    if firstname=='Oshim' or firstname=='Daniel' or firstname=='Onyekachi' or firstname=='Shalom' or firstname=='Edward' or firstname=='Michael' or firstname=='Oluwadamilola' or firstname=='Boluwatife' or firstname=='Mary' or firstname=='Oluwafikunmi' or firstname=='Uchenna':
        if department=='Delivery':
            correct(firstname)
    if firstname=='Jason' or firstname=='Onyiyechi' or firstname=='Otu' or firstname=='Raphael' or firstname=='Victor' or firstname=='Ejike':
        if department=='Administration':
            correct(firstname)
        
    else:
        messagebox.showerror('LOGIN','This employee does not exist')

#create main window
root = tk.Tk()
root.title('LOGIN')
root.geometry('500x200')

#create username label and entry
firstname_label = tk.Label(root, text = 'Firstname(it is case sensitive)')
firstname_label.pack()
firstname_entry = tk.Entry(root, show='*')
firstname_entry.pack()

#create department label and entry
department_label = tk.Label(root, text = 'Department(it is case sensitive)')
department_label.pack()
department_entry = tk.Entry(root, show='*')
department_entry.pack()

#create submit button
submit_button = tk.Button(root, text = 'Submit', command=submit)
submit_button.pack()

#styling the button widget
submit_button.config(fg = 'black', bg = 'pink')

#run the main event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ada\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\ada\AppData\Local\Temp\ipykernel_20380\3603808253.py", line 29, in submit
#     logistics(firstname)
#   File "C:\Users\ada\AppData\Local\Temp\ipykernel_20380\3603808253.py", line 16, in logistics
#     label_3 = tk.Text(window, text='\nNAMES OF EMPLOYEES IN LOGISTICS DEPARTMENT:\n1)ADENIRAN Oluwatamilore  \n2)AGBAKWURU Chiemeziem \n3)ARNIKA Osose \n4)CHUKWUMA Nedi \n5)EZEONYE Makuochukwu \n6)GIWA Moyosore \n7)NWOKOLO Chijindu \n8)NWOTOKUBO	Joseph \n9)OKORO Derek \n10)OSSAI Mary-Cynthia \n11)PETER Owoede')
#                       ^^^^^^
# NameError: name 'window' is not defined
