# %% [markdown]
# # Python - PostgreSQL

# %% [markdown]
# <ul><li>PostgreSQL can be integrated with Python using psycopg2 module.</li><li>psycopg2 is a PostgreSQL database adapter for the Python programming language.</li><li>psycopg2 was written with the aim of being very small and fast, and stable as a rock.</li><li> You do not need to install this module separately because it is shipped, by default, along with Python version 2.5.x onwards.</li></ul>

# %% [markdown]
# # Python psycopg2 Module APIs
#
# If you do not have it installed on your machine then you can use the command to install it as follows:

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\ada\anaconda3\lib\site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# If the above command causes an error then use the command:

# %%
pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp311-cp311-win_amd64.whl.metadata (4.6 kB)
# Downloading psycopg2_binary-2.9.9-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.2 MB 217.9 kB/s eta 0:00:06
#     --------------------------------------- 0.0/1.2 MB 217.9 kB/s eta 0:00:06
#    - -------------------------------------- 0.0/1.2 MB 186.2 kB/s eta 0:00:07
#    - -------------------------------------- 0.0/1.2 MB 186.2 kB/s eta 0:00:07
#    - -------------------------------------- 0.0/1.2 MB 151.3 kB/s eta 0:00:08
#    - -------------------------------------- 0.0/1.2 MB 151.3 kB/s eta 0:00:08
#    - -------------------------------------- 0.0/1.2 MB 151.3 kB/s eta 0:00:08
#    - -------------------------------------- 0.0/1.2 MB 151.3 kB/s eta 0:00:08
#    - -------------------------------------- 0.0/1.2 MB 151.3 kB/s eta 0:00:08
#    - -------------------------------------- 0.1/1.2 MB 90.4 kB/s eta 0:00:13
#    - -------------------------------------- 0.1/1.2 MB 90.4 kB/s eta 0:00:13
#    -- ------------------------------------- 0.1/1.2 MB 96.2 kB/s eta 0:00:12
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    -- ------------------------------------- 0.1/1.2 MB 117.5 kB/s eta 0:00:10
#    --- ------------------------------------ 0.1/1.2 MB 67.2 kB/s eta 0:00:16
#    --- ------------------------------------ 0.1/1.2 MB 67.2 kB/s eta 0:00:16
#    ------ --------------------------------- 0.2/1.2 MB 140.4 kB/s eta 0:00:07
#    ------ --------------------------------- 0.2/1.2 MB 140.4 kB/s eta 0:00:07
#    ------ --------------------------------- 0.2/1.2 MB 140.4 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 140.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 140.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 140.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 140.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 140.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 140.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.2/1.2 MB 125.1 kB/s eta 0:00:08
#    -------- ------------------------------- 0.2/1.2 MB 131.1 kB/s eta 0:00:08
#    -------- ------------------------------- 0.2/1.2 MB 131.1 kB/s eta 0:00:08
#    -------- ------------------------------- 0.2/1.2 MB 131.1 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    -------- ------------------------------- 0.3/1.2 MB 128.9 kB/s eta 0:00:08
#    --------- ------------------------------ 0.3/1.2 MB 100.2 kB/s eta 0:00:09
#    ---------- ----------------------------- 0.3/1.2 MB 106.1 kB/s eta 0:00:09
#    ---------- ----------------------------- 0.3/1.2 MB 106.1 kB/s eta 0:00:09
#    ------------ --------------------------- 0.4/1.2 MB 122.4 kB/s eta 0:00:07
#    ------------ --------------------------- 0.4/1.2 MB 122.4 kB/s eta 0:00:07
#    ------------ --------------------------- 0.4/1.2 MB 122.4 kB/s eta 0:00:07
#    ------------ --------------------------- 0.4/1.2 MB 122.4 kB/s eta 0:00:07
#    ------------- -------------------------- 0.4/1.2 MB 122.9 kB/s eta 0:00:07
#    ------------- -------------------------- 0.4/1.2 MB 122.9 kB/s eta 0:00:07
#    ------------- -------------------------- 0.4/1.2 MB 122.9 kB/s eta 0:00:07
#    ------------- -------------------------- 0.4/1.2 MB 122.9 kB/s eta 0:00:07
#    ------------- -------------------------- 0.4/1.2 MB 118.3 kB/s eta 0:00:07
#    ------------- -------------------------- 0.4/1.2 MB 118.3 kB/s eta 0:00:07
#    ------------- -------------------------- 0.4/1.2 MB 118.3 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 119.4 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 119.4 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 119.4 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 119.4 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 116.5 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 116.5 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 116.5 kB/s eta 0:00:07
#    -------------- ------------------------- 0.4/1.2 MB 116.5 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    --------------- ------------------------ 0.4/1.2 MB 116.1 kB/s eta 0:00:07
#    ----------------- ---------------------- 0.5/1.2 MB 112.7 kB/s eta 0:00:06
#    ----------------- ---------------------- 0.5/1.2 MB 116.2 kB/s eta 0:00:06
#    ----------------- ---------------------- 0.5/1.2 MB 116.2 kB/s eta 0:00:06
kB/s eta 0:00:02
#    ------------------------------------ --- 1.1/1.2 MB 98.9 kB/s eta 0:00:02
#    ------------------------------------ --- 1.1/1.2 MB 98.9 kB/s eta 0:00:02
#    ------------------------------------ --- 1.1/1.2 MB 98.9 kB/s eta 0:00:02
#    ------------------------------------ --- 1.1/1.2 MB 99.5 kB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 99.9 kB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 99.9 kB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 99.9 kB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 99.9 kB/s eta 0:00:01
#    ------------------------------------- -- 1.1/1.2 MB 99.9 kB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 99.6 kB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 99.6 kB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 99.5 kB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 99.5 kB/s eta 0:00:01
#    ---------------------------------------  1.1/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.1/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.1/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.1/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 100.5 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 99.5 kB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The following are important psycopg2 module routines:

# %% [markdown]
# <table border=1 style="font-size:15px;">
#     <tr>
#         <td width=200><b>APIs</b></td><td width=800><b>Description</b></td>
#     </tr>
#     <tr>
#         <td>psycopg2.connect()</td><td>This API opens a connection to the PostgreSQL database.</td>
#     </tr>
#      <tr>
#         <td>connection.cursor()</td><td>This routine creates a cursor which will be used throughout of your database programming with Python.</td>
#     </tr>
#     <tr>
#         <td>cursor.execute()</td><td>This routine executes an SQL statement. The SQL statement may be parameterized (i.e., placeholders instead of SQL literals).</td>
#     </tr>
#      <tr>
#         <td>connection.close()</td><td>DescriptionThis method closes the database connection.</td>
#     </tr>
#     <tr>
#         <td>cursor.fetchone()</td><td>This method fetches the next row of a query result set, returning a single sequence, or None when no more data is available.</td>
#     </tr>
#      <tr>
#         <td>cursor.fetchall()</td><td>This routine fetches all (remaining) rows of a query result, returning a list. An empty list is returned when no rows are available.</td>
#     </tr>
#     <tr>
#         <td>psycopg2.connect()</td><td>This API opens a connection to the PostgreSQL database.</td>
#     </tr>
# </table>

# %% [markdown]
# # Connecting to a Database

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"

# Establish the connection
try:
    connections = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connections.cursor()

    # Execute a SQL query
    cursor.execute("SELECT version();")
    
    # Fetch and print the result of the query
    db_version = cursor.fetchone()
    print(f"PostgreSQL database version: {db_version}")

    # Close the cursor and connection
    cursor.close()
    connections.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL DB: {error}")
# Out:
# Connection to PostgreSQL DB successful
# PostgreSQL database version: ('PostgreSQL 16.1, compiled by Visual C++ build 1937, 64-bit',)

# %% [markdown]
# # Selecting existing Database

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos101_db"
user = "postgres"
password = "cos101"

# Establish the connection
try:
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL SELECT query
    select_query = "SELECT * FROM COMPANY;"

    # Execute the query
    cursor.execute(select_query)

    # Fetch all rows from the executed query
    data = cursor.fetchall()

    print("column", " | ", "column2")
    print("------------------------")
 
    # Iterate through the rows and print them
    for row in data:
        print(f"{row[0]}       |  {row[1]}")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL DB: {error}")
# Out:
# Connection to PostgreSQL DB successful
# column  |  column2
# ------------------------
# 1       |  Chuka
# 2       |  Ethel
# 3       |  Adenike
# 4       |  Hassan
# 5       |  David
# 6       |  Chisom

# %% [markdown]
# # Create a new Database

# %%
import psycopg2
from psycopg2 import sql
# Parameters to connect to the existing PostgreSQL server
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"

# Name of the new database to be created
new_dbname = "cos102_db"

try:
    # Connect to the PostgreSQL server
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL server successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new database
    create_db_query = sql.SQL("CREATE DATABASE {}").format(sql.Identifier(new_dbname))

    # Execute the SQL statement
    cursor.execute(create_db_query)
    print(f"Database '{new_dbname}' created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating the database: {error}")
# Out:
# Connection to PostgreSQL server successful
# Error creating the database: database "cos102_db" already exists

# %% [markdown]
# # Create a Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new table
    create_table_query = """
    CREATE TABLE sst_info (
        id SERIAL PRIMARY KEY,
        name VARCHAR(50) NOT NULL,
        age INT NOT NULL,
        department VARCHAR NOT NULL,
        password VARCHAR NOT NULL
    );
    """

    # Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating table: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Table created successfully

# %% [markdown]
# # INSERT into Table

# %%
import psycopg2

# Database connection parameters
host = "localhost"
port = "5432"
dbname = "cos102_db"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO sst_info (id, name, age, department, password)
    VALUES (%s, %s, %s, %s, %s);
    """
    
    # Data to be inserted
    data_to_insert = (1, "Jamel Ojo", 20, "Software Engineering", "anthelo4")

    # Execute the SQL statement
    cursor.execute(insert_query, data_to_insert)
    print("Data inserted successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error inserting data: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Data inserted successfully

# %% [markdown]
# # SELECT from Table

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'cos102_db',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    select_query = "SELECT * FROM sst_info WHERE age < 30"

    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result = cursor.fetchall()

    # Print the results
    for row in result:
        print(row)

except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# (1, 'Jamel Ojo', 20, 'Software Engineering', 'anthelo4')

# %% [markdown]
# # Class Project I

# %% [markdown]
# Paystack is a Nigerian financial technology company that offers payment processing services to businesses. As a technology company, Paystack solves payment problems for ambitious businesses. Its mission is to help businesses in Africa become profitable, envied, and loved. They make it easy for businesses to accept secure payments from multiple local and global payment channels. They also provide tools to help you retain and acquire new customers. Currently, Paystack is restructuring the team network. It is a diverse, close-knit team on an adventure to build something enduring while learning something new, every day.

# %% [markdown]
# <img src="paystack.jpg">

# %% [markdown]
# With your knowledge in python programming develop an application that creates the database named <b>Paystack_Team</b>. <br>The purpose of the application is to enable management to perform the following queries:
# <ul>
#     <li>Team Members in Revenue Division</li>
#     <li>Team Members in Growth and Product Division whose age is greater than 30 years but less than 35 years</li>
#     <li>Team Members in Modules 1,3 and 5</li>
#     <li>Team Members in Modules 4 and Product Division</li>
# </ul>

# %%
import psycopg2
from psycopg2 import sql

#CREATING A DATABASE
# Parameters to connect to the existing PostgreSQL server
host = "localhost"
port = "5432"
dbname = "postgres"
user = "postgres"
password = "cos101"  # Connect to the default database

# Name of the new database to be created
new_dbname = "Paystack_Team"

try:
    # Connect to the PostgreSQL server
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL server successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new database
    create_db_query = sql.SQL("CREATE DATABASE {}").format(sql.Identifier(new_dbname))

    # Execute the SQL statement
    cursor.execute(create_db_query)
    print(f"Database '{new_dbname}' created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating the database: {error}")
# Out:
# Connection to PostgreSQL server successful
# Database 'Paystack_Team' created successfully

# %%
import psycopg2
#CREATING A TABLE
# Database connection parameters
host = "localhost"
port = "5432"
dbname = "Paystack_Team"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL statement to create a new table
    create_table_query = """
    CREATE TABLE paystack(
        id SERIAL PRIMARY KEY,
        name VARCHAR(50) NOT NULL,
        division VARCHAR(50) NOT NULL,
        age INT NOT NULL,
        module INT NOT NULL
    );
    """

    # Execute the SQL statement
    cursor.execute(create_table_query)
    print("Table created successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error creating table: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Error creating table: relation "paystack" already exists

# %%
import psycopg2
#INSERTING INFO INTO TABLE
# Database connection parameters
host = "localhost"
port = "5432"
dbname = "Paystack_Team"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL INSERT statement
    insert_query = """
    INSERT INTO paystack (id, name,division, age, module)
    VALUES (%s, %s, %s, %s, %s)
    """
    data = [
        (23001,"Oyinda Aina", "Business",32,1), 
        (23002,"Wale Eseyin", "Engineering",28,3),
        (23003,"Khadijah Abu", "Product",30,2),
        (23004,"Onyekachi Mbaike", "Design",37,5),
        (23005,"Seike Ibojo", "Growth",33,4),
        (23006,"Opemipo Aikomo", "Design",28,1),
        (23007,"Ezra Olubi", "Product",30,3),
        (23008,"Alexander Fasoro", "Engineering",35,1),
        (23009,"Stephen Amaza", "Growth",40,2),
        (23010,"Loknan Nanyak", "Engineering",44,5),
        (23011,"Ibrahim Lawal", "Engineering",39,4),
        (23012,"Fisayo Kolawole", "Commercial",27,5),
        (23013,"Emmanuel Quartey", "Growth",31,1),
        (23014,"Awatt Bassey", "Growth",32,2),
        (23015,"Bolaji Akande", "Revenue",30,3),
        (23016,"Mohini Ufeli", "Growth",29,1),
        (23017,"King Makanjuola", "Product",31,4),
        (23018,"Ijeoma Opara", "Revenue",26,2),
        (23019,"Dipo Omobomi", "Product",32,5),
        (23020,"Dapo Awobokun", "Revenue",35,3),
        (23021,"Charles Idem", "Revenue",38,1),
        (23022,"Ayobami Alo", "Product",34,4),
        (23023,"Aminat Badara", "Growth",30,2) 
    ]
    
    # Execute the SQL statement
    for row in data:
        cursor.execute(insert_query, row)
    print("Data inserted successfully")

    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error inserting data: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Error inserting data: duplicate key value violates unique constraint "paystack_pkey"
# DETAIL:  Key (id)=(23001) already exists.

# %%
import psycopg2
    #UPDATING
# Database connection parameters
host = "localhost"
port = "5432"
dbname = "Paystack_Team"
user = "postgres"
password = "cos101"

try:
    # Connect to the PostgreSQL database
    connection = psycopg2.connect(
        host=host,
        port=port,
        dbname=dbname,
        user=user,
        password=password
    )
    connection.autocommit = True  # Enable autocommit mode
    print("Connection to PostgreSQL DB successful")

    # Create a cursor object
    cursor = connection.cursor()
#(23022,"Ayobami Alo", "Product",34,4),
 #       (23023,"Aminat Badara", "Growth",30,2) 
    update_query = """
    UPDATE paystack
    SET name =%s, division = %s, age = %s, module = %s
    WHERE id = %s
    """
    
    # Define the new values for the 'division' and 'age' columns
    new_division = "Product"
    new_age = 34
    new_name = "Ayobami Alo"
    new_module = 4

    # Define the ID of the record you want to update
    record_id = 23022

    # Execute the SQL statement
    cursor.execute(update_query, (new_name,new_division, new_age,new_module,record_id))  # Pass parameters as a tuple
    
    connection.commit()  # Commit the transaction

    print("Record updated successfully")

    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error updating record: {error}")
# Out:
# Connection to PostgreSQL DB successful
# Record updated successfully

# %%
import psycopg2

# Define your database connection parameters
db_params = {
    'dbname': 'Paystack_Team',
    'user': 'postgres',
    'password': 'cos101',
    'host': 'localhost',
    'port': '5432'  # Default is '5432'
}

try:
    # Establish a connection to the database
    connection = psycopg2.connect(**db_params)

    # Create a cursor object
    cursor = connection.cursor()

    # Define the SQL query
    revenue_query = "SELECT id,name FROM paystack WHERE division = 'Revenue'"

    # Execute the SQL query
    cursor.execute(revenue_query)

    # Fetch all the results
    result = cursor.fetchall()

    # Print the results
    print('Team Members in Revenue Division:\n')
    for row in result:
        id_number, name = row 
        print(f"ID: {id_number}, Name: {name}")
        
    # Define the SQL query
    select_query = "SELECT id,name FROM paystack WHERE age > 30 AND age <35"

    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result1 = cursor.fetchall()

    # Print the results
    print('\n\nTeam Members in Growth and Product Division whose age is greater than 30 years but less than 35 years:\n')
    for row1 in result1:
        id_number, name = row1
        print(f"ID: {id_number}, Name: {name}")
        
    # Define the SQL query
    select_query = "SELECT id,name FROM paystack WHERE module IN (1,3,5)"

    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result2 = cursor.fetchall()

    # Print the results
    print('\n\nTeam Members in Modules 1,3 and 5:\n')
    for row2 in result2:
        id_number, name = row2
        print(f"ID: {id_number}, Name: {name}")
        
    # Define the SQL query
    select_query = "SELECT id,name FROM paystack WHERE module = '4' AND division='Product'"

    # Execute the SQL query
    cursor.execute(select_query)

    # Fetch all the results
    result3 = cursor.fetchall()

    # Print the results
    print('\n\nTeam Members in Modules 4 and Product Division:\n')
    for row3 in result3:
        id_number, name = row3
        print(f"ID: {id_number}, Name: {name}")

except Exception as error:
    print(f"Error while connecting to PostgreSQL: {error}")

finally:
    # Close the cursor and connection to clean up
    if cursor:
        cursor.close()
    if connection:
        connection.close()
# Out:
# Team Members in Revenue Division:
#
# ID: 23015, Name: Bolaji Akande
# ID: 23018, Name: Ijeoma Opara
# ID: 23020, Name: Dapo Awobokun
# ID: 23021, Name: Charles Idem
#
#
# Team Members in Growth and Product Division whose age is greater than 30 years but less than 35 years:
#
# ID: 23001, Name: Oyinda Aina
# ID: 23005, Name: Seike Ibojo
# ID: 23013, Name: Emmanuel Quartey
# ID: 23014, Name: Awatt Bassey
# ID: 23017, Name: King Makanjuola
# ID: 23019, Name: Dipo Omobomi
#
#
# Team Members in Modules 1,3 and 5:
#
# ID: 23001, Name: Oyinda Aina
# ID: 23002, Name: Wale Eseyin
# ID: 23004, Name: Onyekachi Mbaike
# ID: 23006, Name: Opemipo Aikomo
# ID: 23007, Name: Ezra Olubi
# ID: 23008, Name: Alexander Fasoro
# ID: 23010, Name: Loknan Nanyak
# ID: 23012, Name: Fisayo Kolawole
# ID: 23013, Name: Emmanuel Quartey
# ID: 23015, Name: Bolaji Akande
# ID: 23016, Name: Mohini Ufeli
# ID: 23019, Name: Dipo Omobomi
# ID: 23020, Name: Dapo Awobokun
# ID: 23021, Name: Charles Idem
#
#
# Team Members in Modules 4 and Product Division:
#
# ID: 23017, Name: King Makanjuola
