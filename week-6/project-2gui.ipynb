# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image,ImageTk

def csc(name,course,jamb,interview,passc):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("CONGRATULATIONS")
    window.geometry('500x200')

    label_1 = tk.Label(window, text=f'YOU HAVE BEEN ADMITTED INTO THE DEPARTMENT OF COMPUTER SCIENCE!!\n')
    label_1.pack()
    label_2 = tk.Label(window, text=f'WELCOME TO THE PORTAL\n')
    label_2.pack()
    label_3 = tk.Label(window, text=f'USER INFO:\n NAME: {name}\n COURSE: {course}\n JAMB SCORE:{jamb}\n Did you pass the interview?: {interview}\n Did you get at least credits in your key subjects?: {passc}')
    label_3.pack()
    root.mainloop()
    
def mcm(name,course,jamb,interview,passc):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("CONGRATULATIONS")
    window.geometry('500x200')
    
    label_1 = tk.Label(window, text=f'YOU HAVE BEEN ADMITTED INTO THE DEPARTMENT OF MASS COMMUNICATION!!\n')
    label_1.pack()
    label_2 = tk.Label(window, text=f'Welcome to the portal\n')
    label_2.pack()
    label_3 = tk.Label(window, text=f'USER INFO:\n NAME: {name}\n COURSE: {course}\n JAMB SCORE: {jamb}\n Did you pass the interview?: {interview}\n Did you get at least credits in your key subjects?: {passc}')
    label_3.pack()
    root.mainloop()

def submit():
    name = name_entry.get()
    course = course_entry.get()
    jamb = int(jamb_entry.get())
    interview = interview_entry.get()
    passc = passc_entry.get()
    
    if course.lower() != 'computer science' or course.lower() != 'mass communication' :
        messagebox.showinfo("ERROR", "TRY CHANGING COURSE TO COMPUTER SCIENCE OR MASS COMMUNICATION \n")
    if course.lower() == 'computer science' and jamb>=250 and passc.lower() == 'yes' and interview.lower() == 'yes':
        csc(name,course,jamb,interview,passc)
    else:
        messagebox.showinfo("ERROR", "YOU ARE NOT QUALIFIED ENOUGH \n")
    if course.lower() == 'mass communication' and jamb>=230 and passc.lower() == 'yes' and interview.lower() == 'yes':
        mcm(name,course,jamb,interview,passc)
    else:
        messagebox.showinfo("ERROR", "YOU ARE NOT QUALIFIED ENOUGH \n")
        
#create main window
root = tk.Tk()
root.title('USER INPUT')
root.geometry('600x300')

#create username label and entry
name_label = tk.Label(root, text = 'Name')
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

#create course label and entry
course_label = tk.Label(root, text = 'Course')
course_label.pack()
course_entry = tk.Entry(root)
course_entry.pack()

#create jamb score label and entry
jamb_label = tk.Label(root, text = 'JAMB Score')
jamb_label.pack()
jamb_entry = tk.Entry(root)
jamb_entry.pack()

#create interview label and entry
interview_label = tk.Label(root, text = 'Did you pass the interview?\n(answer yes or no)')
interview_label.pack()
interview_entry = tk.Entry(root)
interview_entry.pack()

#create pass label and entry
passc_label = tk.Label(root, text = 'Did you get at least credits in your five key courses? \n(answer yes or no)')
passc_label.pack()
passc_entry = tk.Entry(root)
passc_entry.pack()

#create submit button
submit_button = tk.Button(root, text = "Submit", command=submit)
submit_button.pack()

#styling the button widget
submit_button.config(fg = 'blue', bg = 'red')

root.mainloop()

#add a button widget
button = tk.Button(root, command=button_click)
button.pack()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 96
#      93 root.mainloop()
#      95 #add a button widget
# ---> 96 button = tk.Button(root, command=button_click)
#      97 button.pack()
#      99 root.mainloop()
#
# NameError: name 'button_click' is not defined
